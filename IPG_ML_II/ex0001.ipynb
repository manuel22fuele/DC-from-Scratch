# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
data = pd.read_csv('./Datasets/dataset1.txt')
data
# Out:
#      2.08  1.05
# 0    2.05  7.70
# 1    4.53  5.49
# 2    6.23  1.02
# 3    5.35  7.86
# 4    2.88  0.79
# ..    ...   ...
# 344  2.92  2.97
# 345  3.10  8.19
# 346  5.83  5.42
# 347  6.54  3.08
# 348  5.60  9.98
#
# [349 rows x 2 columns]
