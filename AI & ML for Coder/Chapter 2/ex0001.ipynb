# %%
import tensorflow as tf
data = tf.keras.datasets.fashion_mnist

(training_images, training_labels), (test_images, test_labels) = data.load_data()

# %%
training_images = training_images/255.0
test_images = test_images/255.0

# %%
model = tf.keras.models.Sequential([
            tf.keras.layers.Flatten(input_shape=(28, 28)),
            tf.keras.layers.Dense(128, activation=tf.nn.relu),
            tf.keras.layers.Dense(10, activation=tf.nn.softmax),
])

# %%
model.compile(optimizer='adam',
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])

model.fit(training_images, 
          training_labels, 
          epochs=50)
# Out:
# Train on 60000 samples
# Epoch 1/50
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.5009 - acc: 0.8237
# Epoch 2/50
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.3752 - acc: 0.8651
# Epoch 3/50
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.3369 - acc: 0.8778
# Epoch 4/50
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.3133 - acc: 0.8852
# Epoch 5/50
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.2952 - acc: 0.8920
# Epoch 6/50
# 60000/60000 [==============================] - 2s 30us/sample - loss: 0.2794 - acc: 0.8955
# Epoch 7/50
# 60000/60000 [==============================] - 2s 30us/sample - loss: 0.2689 - acc: 0.9010
# Epoch 8/50
# 60000/60000 [==============================] - 2s 30us/sample - loss: 0.2584 - acc: 0.9032
# Epoch 9/50
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.2495 - acc: 0.9072
# Epoch 10/50
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.2400 - acc: 0.9100
# Epoch 11/50
# 60000/60000 [==============================] - 2s 36us/sample - loss: 0.2322 - acc: 0.9130
# Epoch 12/50
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.2243 - acc: 0.9166
# Epoch 13/50
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.2173 - acc: 0.9179
# Epoch 14/50
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.2104 - acc: 0.92072s - loss: 0.2065 - acc: 0. - E
# Epoch 15/50
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.2050 - acc: 0.9233
# Epoch 16/50
# 60000/60000 [==============================] - 2s 38us/sample - loss: 0.1978 - acc: 0.9257
# Epoch 17/50
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.1955 - acc: 0.9275
# Epoch 18/50
# 60000/60000 [==============================] - 2s 38us/sample - loss: 0.1878 - acc: 0.9297
# Epoch 19/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.1836 - acc: 0.9309
# Epoch 20/50
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.1798 - acc: 0.93211s - l
# Epoch 21/50
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.1760 - acc: 0.9342
# Epoch 22/50
# 60000/60000 [==============================] - 2s 31us/sample - loss: 0.1701 - acc: 0.9367
# Epoch 23/50
# 60000/60000 [==============================] - 2s 32us/sample - loss: 0.1664 - acc: 0.9372
# Epoch 24/50
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.1645 - acc: 0.9375
# Epoch 25/50
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.1572 - acc: 0.9410
# Epoch 26/50
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.1548 - acc: 0.9425
# Epoch 27/50
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.1519 - acc: 0.9429
# Epoch 28/50
# 60000/60000 [==============================] - 2s 31us/sample - loss: 0.1486 - acc: 0.9435
# Epoch 29/50
# 60000/60000 [==============================] - 2s 30us/sample - loss: 0.1456 - acc: 0.9461
# Epoch 30/50
# 60000/60000 [==============================] - 2s 28us/sample - loss: 0.1423 - acc: 0.9464
# Epoch 31/50
# 60000/60000 [==============================] - 2s 30us/sample - loss: 0.1402 - acc: 0.9469
# Epoch 32/50
# 60000/60000 [==============================] - 2s 27us/sample - loss: 0.1376 - acc: 0.9482
# Epoch 33/50
# 60000/60000 [==============================] - 2s 27us/sample - loss: 0.1326 - acc: 0.9503
# Epoch 34/50
# 60000/60000 [==============================] - 2s 27us/sample - loss: 0.1316 - acc: 0.9499
# Epoch 35/50
# 60000/60000 [==============================] - 2s 30us/sample - loss: 0.1284 - acc: 0.9514
# Epoch 36/50
# 60000/60000 [==============================] - 2s 27us/sample - loss: 0.1270 - acc: 0.9514
# Epoch 37/50
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.1233 - acc: 0.9529
# Epoch 38/50
# 60000/60000 [==============================] - 2s 28us/sample - loss: 0.1222 - acc: 0.9535
# Epoch 39/50
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.1210 - acc: 0.9550
# Epoch 40/50
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.1191 - acc: 0.9545
# Epoch 41/50
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.1140 - acc: 0.9573
# Epoch 42/50
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.1149 - acc: 0.9567
# Epoch 43/50
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.1103 - acc: 0.95860s - loss:
# Epoch 44/50
# 60000/60000 [==============================] - 2s 31us/sample - loss: 0.1097 - acc: 0.9581
# Epoch 45/50
# 60000/60000 [==============================] - 2s 30us/sample - loss: 0.1080 - acc: 0.9593
# Epoch 46/50
# 60000/60000 [==============================] - 2s 35us/sample - loss: 0.1063 - acc: 0.9604
# Epoch 47/50
# 60000/60000 [==============================] - 2s 31us/sample - loss: 0.1052 - acc: 0.9615
# Epoch 48/50
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.1039 - acc: 0.9612
# Epoch 49/50
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.1029 - acc: 0.9615
# Epoch 50/50
# 60000/60000 [==============================] - 2s 31us/sample - loss: 0.0990 - acc: 0.9640

# %% [markdown]
# #### Testing the data

# %%
model.evaluate(test_images, test_labels)
# Out:
# 10000/10000 [==============================] - 0s 19us/sample - loss: 0.5297 - acc: 0.8885
# [0.5297449476987124, 0.8885]

# %% [markdown]
# #### Exploring the Model Output

# %%
classifications = model.predict(test_images)
print(classifications[0])
print(test_labels[0])
# Out:
# [1.8627270e-19 1.1095033e-15 1.7427640e-17 9.0862212e-25 1.7828151e-30
#  8.0773532e-10 1.6843759e-18 4.3325805e-08 1.3417808e-17 1.0000000e+00]
# 9
