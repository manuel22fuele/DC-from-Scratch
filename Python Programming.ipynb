# %% [markdown]
# ### Recursion

# %%
def fibonacci(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else: return fibonacci(n-1) + fibonacci(n-2)

# %%
fibonacci(7)
# Out:
# 13

# %%
def somaAnterior(n):
    if n <= 1:
        return n
    return n + somaAnterior(n-1)

# %%
somaAnterior(10)
# Out:
# 55

# %%
sum = 0

for i in range(1, 30000):
    sum += 0.11

print('%.6f' % sum)
# Out:
# 3299.890000
